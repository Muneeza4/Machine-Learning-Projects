# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Generate synthetic data for age, experience, and salary

np.random.seed(0)


# Independent variables

age = np.random.randint(22, 60, 100)         # Random ages between 22 and 59
experience = np.random.randint(0, 40, 100)   # Random years of experience between 0 and 39

# Dependent variable

salary = 3000 + 200 * age + 100 * experience + np.random.normal(0, 1000, 100)  # Linear combination with some noise


# Create DataFrame

data = {
    'Age': age,
    'Experience': experience,
    'Salary': salary
}


df = pd.DataFrame(data)

# Display the first few rows of the dataset

print(df.head())
df.shape
# Out:
#    Age  Experience        Salary
# 0   22           3   9043.954420
# 1   25          18   8981.779039
# 2   25          35  11582.709936
# 3   31          20   9908.941545
# 4   41          17  12238.895768
# (100, 3)

# %%
sns.pairplot(data = df)
plt.show()
# Out:
# C:\Users\Muneeza\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
x = df[['Age', 'Experience']]  # Features
y = df['Salary']               # Target variable

# %%
# Split data into training and testing sets (80% train, 20% test)

x_train, x_test, y_train, y_test = train_test_split(x, y_pred, test_size=0.2, random_state=42)

# %%
# Initialize the model

model = LinearRegression()


# Fit the model

model.fit(x,y)
# Out:
# LinearRegression()

# %%
# Predict

y_pred = model.predict(x)


# Model evaluation

print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error:', mean_squared_error(y, y_pred))
print('Coefficient of determination (R^2):', r2_score(y, y_pred))
# Out:
# Coefficients: [194.43906953  94.5451029 ]
# Intercept: 3190.4200465114627
# Mean squared error: 1062443.7318972205
# Coefficient of determination (R^2): 0.8415898455851272

# %%
model.score(x_test,y_test)*100
# Out:
# 100.0
