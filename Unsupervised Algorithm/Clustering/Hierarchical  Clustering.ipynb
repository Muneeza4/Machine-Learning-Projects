# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris

# %%
# Load the Iris dataset

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
# Preprocess the data (scaling)

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
data = pd.DataFrame(scaled_data)

# %%
sns.pairplot(data = df)
plt.show()
# Out:
# C:\Users\Muneeza\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
Z = linkage(data, metric='euclidean',method = 'complete')

# %%
plt.figure(figsize=(20, 20))
plt.title("Dendrogram for Iris Dataset")
dendrogram(Z)
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# %%
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
model.fit(data)
# Out:
# C:\Users\Muneeza\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# AgglomerativeClustering(affinity='euclidean', n_clusters=3)

# %%
df["predict"]= model.fit_predict(df)
# Out:
# C:\Users\Muneeza\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
sns.pairplot(data = df, hue = "predict" )
plt.show()
# Out:
# C:\Users\Muneeza\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
